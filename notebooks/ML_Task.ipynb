# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned data
df = pd.read_csv('path_to_you_csv_file',on_bad_lines='skip')

# Display basic info
print(df.info())
print(df.describe())

# Visualize accident severity distribution
sns.countplot(x='Severity', data=df)
plt.title('Severity Distribution')
plt.show()

# Select only numeric columns for correlation matrix
numeric_cols = df.select_dtypes(include='number')

# Generate correlation matrix
correlation_matrix = numeric_cols.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm")
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     12 non-null     object
#  1   Severity               12 non-null     int64
#  2   Start_Time             12 non-null     object
#  3   End_Time               12 non-null     object
#  4   Start_Lat              12 non-null     float64
#  5   Start_Lng              12 non-null     float64
#  6   End_Lat                12 non-null     float64
#  7   End_Lng                12 non-null     float64
#  8   Distance(mi)           12 non-null     float64
#  9   Description            12 non-null     object
#  10  Number                 12 non-null     object
#  11  Street                 12 non-null     object
#  12  Side                   12 non-null     object
#  13  City                   12 non-null     object
#  14  County                 12 non-null     object
#  15  State                  12 non-null     object
#  16  Zipcode                12 non-null     object
#  17  Country                12 non-null     object
#  18  Timezone               12 non-null     object
#  19  Airport_Code           12 non-null     object
#  20  Weather_Timestamp      12 non-null     object
#  21  Temperature(F)         12 non-null     object
#  22  Wind_Chill(F)          12 non-null     float64
#  23  Humidity(%)            12 non-null     float64
#  24  Pressure(in)           12 non-null     float64
#  25  Visibility(mi)         12 non-null     float64
#  26  Wind_Direction         12 non-null     object
#  27  Wind_Speed(mph)        12 non-null     object
#  28  Precipitation(in)      12 non-null     float64
#  29  Weather_Condition      12 non-null     object
#  30  Amenity                12 non-null     object
#  31  Bump                   12 non-null     bool
#  32  Crossing               12 non-null     bool
#  33  Give_Way               12 non-null     bool
#  34  Junction               12 non-null     bool
#  35  No_Exit                12 non-null     bool
#  36  Railway                12 non-null     bool
#  37  Roundabout             12 non-null     bool
#  38  Station                12 non-null     bool
#  39  Stop                   12 non-null     bool
#  40  Traffic_Calming        12 non-null     bool
#  41  Traffic_Signal         12 non-null     bool
#  42  Turning_Loop           12 non-null     object
#  43  Sunrise_Sunset         12 non-null     object
#  44  Civil_Twilight         12 non-null     object
#  45  Nautical_Twilight      12 non-null     object
#  46  Astronomical_Twilight  5 non-null      object
# dtypes: bool(11), float64(10), int64(1), object(25)
# memory usage: 3.6+ KB
# None
#         Severity  Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# count  12.000000  12.000000   12.000000  12.000000   12.000000     12.000000
# mean    2.416667  37.499269 -101.331287  37.499825 -101.331933      1.166667
# std     0.996205   6.434699   21.021274   6.434727   21.021415      0.833757
# min     1.000000  25.761680 -122.675026  25.762200 -122.676000      0.400000
# 25%     2.000000  33.976427 -120.146466  33.976825 -120.147500      0.575000
# 50%     2.000000  37.276594 -106.806744  37.277150 -106.807250      0.800000
# 75%     3.000000  41.998648  -83.338931  41.999200  -83.339500      1.500000
# max     4.000000  47.606209  -71.058291  47.606700  -71.059000      3.000000
#
#        Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# count      12.000000    12.000000     12.000000       12.000000
# mean       64.666667    57.000000     32.956667        9.909167
# std        11.039873    12.314072     10.091415        6.458322
# min        49.000000    40.000000     29.890000        5.000000
# 25%        55.500000    48.750000     29.997500        7.375000
# 50%        63.500000    57.500000     30.050000        8.000000
# 75%        71.500000    61.250000     30.105000        9.625000
# max        85.000000    84.000000     65.000000       29.910000
#
#        Precipitation(in)
# count          12.000000
# mean            1.308333
# std             4.312816
# min             0.000000
# 25%             0.000000
# 50%             0.025000
# 75%             0.125000
# max            15.000000
